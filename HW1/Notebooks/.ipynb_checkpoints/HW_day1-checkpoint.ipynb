# %% [markdown]
# # План -- залог успеха
#
# 1. Предобрабатываем и анализируем тексты
#     * Строим облако слов в т.ч.
# 2. Пробуем разные подходы к токенизации
# 3. Исключаем и не исключаем стоп-слова
# 4. Да и нет лемматизации//стеммингу
# 5. Простые векторизации: bag-of-words, CountVectorizer, TfIdfVectorizer
#     * Уни-, би- и другие граммы
# 6. Модели: логрег, SVM
# 7. Катбуст с текстовыми фичами
# 8. Аналитика результатов
# 9. Предложения ребят(ам), как можно улучшить прогноз
#     * языковые фичи;
#     * аугментации текстов;
#     * ...

# %% [markdown]
# На любые вопросы по этой домашке постарается ответить Савелий (TG: @Savely_Prokhorov). Не стесняйтесь спрашивать, ему будет приятно помочь.
#
# И помните:
#
# > Не существует глупых вопросов!
#
# Вы можете что-то не знать из того, что нужно для полного выполнения этой домашки -- и это не стыдно. Давайте учиться вместе!

# %% [markdown]
# В этом ноутбуке мы выделили **жирным** некоторые рекомендации по тому, что можно улучшить в бейзлайне, чтобы попытаться выбить скор получше.
#
# Модели давайте сравнивать по $R^2$ ([Вики про коэффициент детерминации](https://en.wikipedia.org/wiki/Coefficient_of_determination))
#
#
#
# > **Сохраняйте промежуточные результаты: некоторые алгоритмы отрабатывают довольно долго, обидно будет потерять результаты вычислений; к тому же сохранённые модели (вместе с пайплайнами предобработки, если они отличаются) будет легче состекать**
#
#
#
# > А ещё вам могут быть полезны [пайплайны из sklearn](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html). Если хорошо приспособите -- будет довольно удобно

# %%
# !pip install pymorphy2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 2.8 MB/s eta 0:00:00
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 76.1 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=157d79214cc9b0d8f4033b35a25348a50d45dc7be3e4abcee11106ac425b8eff
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Lasso

import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer

from gensim.models import Word2Vec

from tqdm import tqdm
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [12, 8]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\nikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # Загрузка данных

# %%
df_train = pd.read_csv('../Datasets/vacancies_train.csv')
df_train
# Out:
#                                                     name          experience  \
# 0                                    Водитель-экспедитор       От 3 до 6 лет
# 1                    Кладовщик-комплектовщик/оператор 1С  От 1 года до 3 лет
# 2      Продавец магазина "Магнит" (Кировский р-он, В....           Нет опыта
# 3                       Администратор магазина (ТЦ Spar)  От 1 года до 3 лет
# 4                              Мойщик посуды (кулинария)           Нет опыта
# ...                                                  ...                 ...
# 16624             Полицейский специального полка полиции           Нет опыта
# 16625           Врач стоматолог-ортопед (г. Новосибирск)           Нет опыта
# 16626                                          Фармацевт  От 1 года до 3 лет
# 16627                             Геодезист (автодороги)  От 1 года до 3 лет
# 16628    Специалист-эксперт отдела правового обеспечения           Нет опыта
#
#              schedule        employment  \
# 0         Полный день  Полная занятость
# 1         Полный день  Полная занятость
# 2      Сменный график  Полная занятость
# 3         Полный день  Полная занятость
# 4      Сменный график  Полная занятость
# ...               ...               ...
# 16624     Полный день  Полная занятость
# 16625     Полный день  Полная занятость
# 16626     Полный день  Полная занятость
# 16627  Вахтовый метод  Полная занятость
# 16628     Полный день  Полная занятость
#
#                                              description  \
# 0      Водитель-экспедитор категории В,С (а\м ГАЗЕЛЬ ...
# 1      Обязанности:   Списывание материалов в произво...
# 2      В крупнейшую Федеральную сеть магазинов "Магни...
# 3      Крупная федеральная сеть магазинов мужской и ж...
# 4      Обязанности:  Уборка производственных площадей...
# ...                                                  ...
# 16624  Обязанности:   обеспечение общественного поряд...
# 16625  Обязанности:  Оказывает квалифицированную меди...
# 16626  Условия:  официальное оформление по ТК РФ; гра...
# 16627  Обязанности:  своевременное и качественное вып...
# 16628  Обязанности:  правовое сопровождение деятельно...
#
#                                               key_skills   salary
# 0                                                     []  42500.0
# 1      ['знание пк', 'работа в 1С', 'Работа в команде...  50000.0
# 2                                                     []  31500.0
# 3                                                     []  36700.0
# 4      ['Пользователь ПК', 'Грамотная речь', 'Работа ...  37000.0
# ...                                                  ...      ...
# 16624  ['Грамотная речь', 'Обучение и развитие', 'Упр...  67500.0
# 16625                       ['Медицинская документация']  50000.0
# 16626  ['Пользователь ПК', 'Работа в команде', 'Грамо...  50000.0
# 16627                                                 []  75000.0
# 16628  ['Грамотная речь', 'Пользователь ПК', 'Умение ...  25000.0
#
# [16629 rows x 7 columns]

# %%
df_test = pd.read_csv('vacancies_test.csv', index_col=0) # честный тест -- для него у вас не будет ответов
# а вот на валидацию можете себе, сколько нужно, откусить от трейна
df_test
# Out:
#                                                    name          experience  \
# 0                                     Главный бухгалтер         Более 6 лет
# 1                           Ассистент врача-стоматолога  От 1 года до 3 лет
# 2                                  Менеджер по продажам  От 1 года до 3 лет
# 3                                              Менеджер  От 1 года до 3 лет
# 4                                 Администратор хостела           Нет опыта
# ...                                                 ...                 ...
# 5538  Специалист по дистанционному контролю качества...  От 1 года до 3 лет
# 5539                               Продавец-консультант           Нет опыта
# 5540                 Фельдшер скорой медицинской помощи       От 3 до 6 лет
# 5541                               Продавец-консультант           Нет опыта
# 5542   Торговый представитель (Колпино, Тосно, Кировск)  От 1 года до 3 лет
#
#               schedule        employment  \
# 0          Полный день  Полная занятость
# 1       Сменный график  Полная занятость
# 2          Полный день  Полная занятость
# 3          Полный день  Полная занятость
# 4       Сменный график  Полная занятость
# ...                ...               ...
# 5538  Удаленная работа  Полная занятость
# 5539       Полный день  Полная занятость
# 5540    Сменный график  Полная занятость
# 5541       Полный день  Полная занятость
# 5542       Полный день  Полная занятость
#
#                                             description  \
# 0     Обязанности:Осуществление организации бухгалте...
# 1     Обязанности:  Ассистировать врачу стоматологу,...
# 2     Если ты:    хочешь построить карьеру в банковс...
# 3       Динамично развивающаяся на протяжении 17 лет...
# 4     ВОЗМОЖНА РАБОТА С ПРОЖИВАНИЕМ Обязанности:  Пр...
# ...                                                 ...
# 5538  Обязанности:   проводить визуальный контроль а...
# 5539  Компания ONE SMOKE приглашает к сотрудничеству...
# 5540  Обязанности:  Осуществляет оказание скорой мед...
# 5541  Мечтаешь быть уникальной? Хочешь дарить клиент...
# 5542  Компания ТД Мегаполис - крупный дистрибьютор п...
#
#                                              key_skills
# 0     ['1С: Предприятие 8', '1C: Предприятие', 'Рабо...
# 1     ['Пользователь ПК', 'Работа в команде', 'Умени...
# 2                                                    []
# 3     ['Оценка потребностей клиентов', 'оформление д...
# 4                                                    []
# ...                                                 ...
# 5538  ['Удаленная работа', 'Грамотная речь', 'Пользо...
# 5539  ['Пользователь ПК', 'Розничная торговля', 'Раб...
# 5540                                                 []
# 5541  ['Работа в команде', 'Грамотная речь', 'Ориент...
# 5542  ['Традиционная розница', 'работа с текущей баз...
#
# [5543 rows x 6 columns]

# %% [markdown]
# # Простейший EDA

# %% [markdown]
# Для начала посмотрим на распределение таргета в трейне. Видим выбросы совсем низкой зарплаты. **Посмотрите на описание вакансий с выбросами** -- это может помочь объяснить их.

# %%
sns.histplot(df_train.salary, bins=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
# your code here
low_salaries = df_train[df_train['salary'] <= 6000]
for index, row in low_salaries.iterrows():
    print(f"{row['name']}\n{row['salary']}\n{row['description']}\n\n")
# Out:
# Ведущий специалист/Руководитель тендерного отдела
# 55.0
# Компания-поставщик медицинских расходных материалов ищет руководителя тендерного отдела в офис в г. Бердске. Готовы рассматривать специалистов с хорошим опытом в сфере государственных закупок с минимальным опытом руководства. Ставка временная, на период отпуска по уходу за ребенком основного сотрудника. Обязанности:  Оперативное управление сотрудниками, наставничество, обучение; Мониторинг опубликованных аукционов в ЕИС; Подготовка коммерческих предложений; Оформление договоров поставки; Ведение реестра коммерческих предложений, реестра договоров, реестров закупок; Изучение аукционной /конкурсной документации опубликованной Заказчиком, анализ их на соответствие действующему законодательству (ФЗ-44, ФЗ-223); Подготовка и подача заявок для участия в торговых процедурах совместно со специалистами (аукционы, конкурсы, запросы котировок) (ФЗ-44, ФЗ-223); Подача запросов на разъяснение аукционной / конкурсной документации при необходимости; Участие в торговых процедурах, в соответствии с целями и задачами Компании; Подача жалоб в ФАС; Проверка контрактов‚ заключаемых по итогам проводимых торговых процедур, составление протоколов разногласий по контрактам; Оформление банковских гарантий; Заведение контрактов в базу 1С; Отслеживание возврата денежных средств, внесенных в качестве обеспечения заявок.  Требования:  Юридическая грамотность; Отличное знание 44-ФЗ и 223-ФЗ, новое в законодательстве; Опыт работы от 3 лет по направлению тендеры; Навык работы на электронных торговых площадках; Опыт ведения нескольких проектов одновременно; Умение работать в режиме многозадачности.  Условия:  Пятидневная рабочая неделя. Работа по срочному трудовому договору (на период отсутствия основного работника) Оформление по Трудовому кодексу РФ Комфортный офис в г. Бердске
#
#
# Сотрудник на пересчет товара
# 2100.0
# Обязанности: ✓ Ежедневно выполнять цикличные действия (вести календарь, согласовывать встречи)✓ Искать и структурировать информацию✓ Не бояться новых задач и уметь находить пути их решения✓ Помощь в ведении моих страниц (размещать посты, подбирать картинки, транскрибировать аудио, отслеживать количество сторис и размещать их)✓ Поиск исполнителей для типовых задач и контроль выполнения (например, транскрибация текста, дизайн, таргетинг и тд)✓ Подготовка презентаций для выступлений (если есть навык оформления - это плюс)✓ Поиск площадок для выступлений и интервьюеров✓ Личные вопросы (заказ еды, покупка билетов, бронь отелей и т.д.) Требования:1. У тебя есть опыт работы бизнес-ассистентом от 1 месяца2. У тебя аналитический склад ума, любишь считать и работать с цифрами2. Понимаешь что такое ответственность3. Работаешь в рамках дедлайнов и соблюдаешь их без напоминаний4. Ты проактивный — не ждешь задач, а инициируешь их самостоятельно5. Внимательность - твое второе имя6. У тебя есть способность думать, а не просто выполнять задачи как по приказу7. Понятия честность и исполнительность для тебя не пустой звук Условия: пн - пт - быть на связи с 9 до 19.00 (мск), оперативно реагировать на мои вопросы, суббота - 1-2 часа, вс - выходной✓ занятость - 4-6 часов (нагрузка на начальном этапе неравномерная, иногда 6 полных часов, иногда - 2 задачи на 1,5 часа, главное - результат в виде завершенных задач)✓ испытательный срок - 2 месяца (при отличных результатах возможно досрочное прекращение)✓ зарплата - оклад на испытательный срок до 10 000 руб. После окончания испытательного срока - рост ответственности и повышение заработной платы до уровня моего заместителя.Что ты получишь:- прохождение необходимых профильных курсов с оплатой от компании для повышения компетенций- перспектива карьерного роста до уровня управляющего- твой личный рост в сфере предпринимательства- нетворкинг: знакомство и общение с топовыми менеджерами и владельцами компаний- навыки ведения бизнес коммуникаций- классный круг общения среди предпринимателей и владельцев компаний
#
#
# Офис-менеджер
# 6000.0
# Обязанности:  Составление писем; Ведение документооборота; Работа с курьерскими службами, транспортными компаниями; Взаимодействие с государственными органами; Отправка/прием почты.  Требования:  Уверенный пользователь MS Office; Грамотная речь, ответственность, аккуратность, пунктуальность.  Условия:  Свободный график, каждый день в офис приезжать не нужно; Можно совмещать с учебой или основной работой.

# %% [markdown]
# Как видно из описания вакансий с низким значением зп, оплата указана за выход, за одну или за несколько смен или вовсе похожа на мусор

# %% [markdown]
# В логарифмированной шкале распределение больше похоже на нормальное (ежели отбросить левый хвост с выбросом). **Подумайте, возможно стоит как-нибудь обработать выбросы или их удалить**

# %%
sns.histplot(np.log10(df_train.salary + 1), bins=100)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
df_train.name.value_counts()
# Out:
# name
# Менеджер по продажам                                          208
# Продавец-консультант                                          180
# Менеджер по работе с клиентами                                111
# Кладовщик                                                     111
# Бухгалтер                                                     108
#                                                              ...
# Упаковщица/Упаковщик                                            1
# Помощник официанта,ранер                                        1
# Менеджер по продаже оборудования для общепита и торговли        1
# Электросварщик на полуавтомат (морской регистр, НАКС НГДО)      1
# Специалист-эксперт отдела правового обеспечения                 1
# Name: count, Length: 9915, dtype: int64

# %%
# your code here

# Определение критерия выброса, например, будем удалять значения зарплат,
# выходящие за пределы трех стандартных отклонений от среднего
mean_salary = df_train['salary'].mean()
std_salary = df_train['salary'].std()
cutoff = 3 * std_salary

# Фильтрация данных для удаления выбросов
filtered_df = df_train.loc[abs(df_train['salary'] - mean_salary) <= cutoff]

# Удалим также значения <= 10000, так как зарплаты там, в основном, указаны за выход или смену
filtered_df = filtered_df.loc[filtered_df['salary'] > 10000]
filtered_df
# Out:
#                                                     name          experience  \
# 0                                    Водитель-экспедитор       От 3 до 6 лет
# 1                    Кладовщик-комплектовщик/оператор 1С  От 1 года до 3 лет
# 2      Продавец магазина "Магнит" (Кировский р-он, В....           Нет опыта
# 3                       Администратор магазина (ТЦ Spar)  От 1 года до 3 лет
# 4                              Мойщик посуды (кулинария)           Нет опыта
# ...                                                  ...                 ...
# 16624             Полицейский специального полка полиции           Нет опыта
# 16625           Врач стоматолог-ортопед (г. Новосибирск)           Нет опыта
# 16626                                          Фармацевт  От 1 года до 3 лет
# 16627                             Геодезист (автодороги)  От 1 года до 3 лет
# 16628    Специалист-эксперт отдела правового обеспечения           Нет опыта
#
#              schedule        employment  \
# 0         Полный день  Полная занятость
# 1         Полный день  Полная занятость
# 2      Сменный график  Полная занятость
# 3         Полный день  Полная занятость
# 4      Сменный график  Полная занятость
# ...               ...               ...
# 16624     Полный день  Полная занятость
# 16625     Полный день  Полная занятость
# 16626     Полный день  Полная занятость
# 16627  Вахтовый метод  Полная занятость
# 16628     Полный день  Полная занятость
#
#                                              description  \
# 0      Водитель-экспедитор категории В,С (а\м ГАЗЕЛЬ ...
# 1      Обязанности:   Списывание материалов в произво...
# 2      В крупнейшую Федеральную сеть магазинов "Магни...
# 3      Крупная федеральная сеть магазинов мужской и ж...
# 4      Обязанности:  Уборка производственных площадей...
# ...                                                  ...
# 16624  Обязанности:   обеспечение общественного поряд...
# 16625  Обязанности:  Оказывает квалифицированную меди...
# 16626  Условия:  официальное оформление по ТК РФ; гра...
# 16627  Обязанности:  своевременное и качественное вып...
# 16628  Обязанности:  правовое сопровождение деятельно...
#
#                                               key_skills   salary
# 0                                                     []  42500.0
# 1      ['знание пк', 'работа в 1С', 'Работа в команде...  50000.0
# 2                                                     []  31500.0
# 3                                                     []  36700.0
# 4      ['Пользователь ПК', 'Грамотная речь', 'Работа ...  37000.0
# ...                                                  ...      ...
# 16624  ['Грамотная речь', 'Обучение и развитие', 'Упр...  67500.0
# 16625                       ['Медицинская документация']  50000.0
# 16626  ['Пользователь ПК', 'Работа в команде', 'Грамо...  50000.0
# 16627                                                 []  75000.0
# 16628  ['Грамотная речь', 'Пользователь ПК', 'Умение ...  25000.0
#
# [16281 rows x 7 columns]

# %%
sns.histplot(filtered_df.salary, bins=100)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.histplot(np.log10(filtered_df.salary + 1), bins=100)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %% [markdown]
# По графику ниже, видим, что вакансий для опытных соискателей сравнительно немного. **Попробуйте визуализировать совместное распределение опыта работы и предлагаемой зп**

# %%
sns.histplot(df_train.experience)
# Out:
# <AxesSubplot:xlabel='experience', ylabel='Count'>

# %%
# your code here

# %% [markdown]
# Вакансий с графиком занятости, отличной от полной, совсем не много. **Наверное стоит отдельно посмотреть, не отличается ли описание таких вакансий**.

# %%
sns.histplot(df_train.schedule)
# Out:
# <AxesSubplot:xlabel='schedule', ylabel='Count'>

# %%
sns.histplot(df_train.employment)
# Out:
# <AxesSubplot:xlabel='employment', ylabel='Count'>

# %%
# your code here
descr = df_train.loc[df_train['employment'] != 'Полная занятость']
for _, row in descr.head(5).iterrows():
    print(row['description'] + '\n')
# Out:
# Работа на территории работодателя: р-н Кущевский, с. Полтавченское, ул Трудовая, д. 3, корп. б Обязанности:   Оказывает доврачебную медицинскую помощь, осуществляет забор биологических материалов для лабораторных исследований.   Осуществляет уход за больными в медицинской организации и на дому.   Осуществляет стерилизацию медицинских инструментов, перевязочных средств и предметов ухода за больными.   Ассистирует при проведении врачом лечебно-диагностических манипуляций и малых операций в амбулаторных и стационарных условиях.   Проводит подготовку пациентов к различного рода исследованиям, процедурам, операциям, к амбулаторному приему врача.   Обеспечивает выполнение врачебных назначений.   Осуществляет учет, хранение, использование лекарственных средств и этилового спирта.   Ведет персональный учет, информационную (компьютерную) базу данных состояния здоровья обслуживаемого населения.   Руководит деятельностью младшего медицинского персонала.   Ведет медицинскую документацию.   Проводит санитарно-просветительную работу среди больных и их родственников по укреплению здоровья и профилактике заболеваний, пропаганде здорового образа жизни.   Осуществляет сбор и утилизацию медицинских отходов.   Осуществляет мероприятия по соблюдению санитарно-гигиенического режима, правил асептики и антисептики, условий стерилизации инструментов и материалов, предупреждению постинъекционных осложнений, гепатита, ВИЧ-инфекции.       Требования: Профильное образование + "Сестринское дело в педиатрии" Условия:  С неполным рабочим днем 0,5 ставки Социальный пакет
#
# Обязанности:  Мытье оборудования, ресторана, замена масла.  Требования:  Желание работать в сфере общественного питания; Доброжелательность и энергичность Желательно иметь медицинскую книжку  Условия:  Работа в ночную смену с 21.00 до 09.00 Официальное трудоустройство. График работы 2/2 или 3/3 по договоренности. Стабильная заработная плата 2 раза в месяц без задержек.
#
# Обязанности:  встреча пациентов, информирование,координирование консультирование по услугам медицинского центра оформление и распечатка договора занесение анализов от пациента в 1С оформление направлений  Требования:  готовность работать в условиях многозадачности умение работать с большим объемом информации высокий уровень ответственности среднее/высшее образование, возможно совмещение с учебной занятостью  Условия:  график с 7.00-13.00 будни, выходные с 8.00-13.00 работа в крупной развивающейся компании обучение и развитие за счет компании стабильная и своевременная оплата труда
#
# В онлайн-школе “Тетрика” занимаются ученики 1–11 классов. Наши уроки дополняют школьную программу, помогают улучшить оценки, сдать ЕГЭ/ОГЭ Время работы выбираете самостоятельно, но обязательно в промежутке между 13:00-21:00 по Московскому времени и не менее 40 часов в неделю Требования:  У Вас должен быть опыт работы преподавателем/репетитором по информатике от 2х лет. Возможно Вы студент от 3 курса и выше; Педагогическое образование или высшее образование профильное по преподаваемому предмету Уверенный пользователь ПК (MS Office), интерактивной доски. Подготовка к ОГЭ/ЕГЭ обязательно  Условия:  Работа из дома Платформа для занятий с видео связью и готовыми заданиями Постоянный поток учеников у вас есть ноутбук с камерой, микрофоном и стабильным Интернет-соединением.  Как вы будете работать:  Вы самостоятельно изучите инструкцию по работе с платформой и разместите обучающие материалы на интерактивной доске   Вы с учеником составите расписание и начнете заниматься на удобной интерактивной платформе.  Наша команда будет сопровождать вас на всех этапах работы с нами
#
# Работа на территории работодателя: г Геленджик, с Криница, б-р Приморский, д. 2, корп. Я Обязанности:   Выполняет профилактические, лечебные, санитарно-гигиенические мероприятия, назначенные врачом-диетологом ЛПУ.   Осуществляет контроль хранения запаса продуктов питания, качества пищевых продуктов при их поступлении на склад и пищеблок.   Осуществляет контроль за работой пищеблока.   Ежедневно подготавливает под контролем диетолога и при участии заведующего производством меню-раскладку (меню-требование) в соответствии с картотекой блюд (наименование блюд, их количество, номера диет, количество продуктов на все блюда, общее количество продуктов).   Осуществляет контроль за правильностью закладки продуктов в котел и бракераж готовой пищи (снятие пробы), за выполнением технологических методов приготовления блюд для различных диет, за правильностью отпуска блюд с пищеблока в отделение в соответствии с раздаточной ведомостью, за санитарным состоянием раздаточных и буфетных отделений, инвентаря, посуды, а также за выполнением правил личной гигиены работниками раздаточных.   Внедряет принципы рационального и лечебного питания с учетом норм физиологических потребностей, биологических свойств пищевых продуктов в диетотерапии, заболеваний, сохранения пищевой ценности продуктов питания при хранении и кулинарной обработке.   Проводит учебные занятия со средним медицинским персоналом и работниками кухни по организации лечебного питания в ЛПУ. Ведет медицинскую документацию.   Осуществляет контроль за своевременностью проведения профилактических осмотров работников пищеблока и буфетных; отстраняет и запрещает работу лицам, не прошедшим предварительного или периодического медицинского осмотров, больным гнойничковыми и кишечными заболеваниями.   Оказывает доврачебную помощь при неотложных ситуациях.   Осуществляет сбор и утилизацию медицинских отходов.   Осуществляет мероприятия по соблюдению санитарно-гигиенического режима в помещении, правил асептики и антисептики, условий стерилизации инструментов и материалов, предупреждению постинъекционных осложнений, гепатита, ВИЧ-инфекции.   Требования:   Профильное образование (Диетическая сестра).   Условия:   Социальный пакет.

# %% [markdown]
# Посмотрим, как часто различные требуемые навыки встречаются в поле `key_skills`. Логично предположить, что некоторые из них оказывают значимое влияние на предлагаемую зарплату. **Попробуйте проверить эту гипотезу**

# %%
from ast import literal_eval
from collections import OrderedDict

# %%
skills_count = dict()

for skill_list in df_train.key_skills:
    list_of_skills = literal_eval(skill_list)
    for skill in list_of_skills:
        if skill not in skills_count:
            skills_count[skill] = 1
        else:
            skills_count[skill] += 1

skills_count = {k: v for k, v in sorted(skills_count.items(), key=lambda item: item[1], reverse=True)}
skills_count
# Out:
# {'Работа в команде': 2773,
#  'Пользователь ПК': 2638,
#  'Грамотная речь': 2226,
#  'Умение работать в команде': 1152,
#  'Активные продажи': 1066,
#  'Деловое общение': 851,
#  'Навыки продаж': 700,
#  'Телефонные переговоры': 649,
#  'Ведение переговоров': 630,
#  'Организаторские навыки': 588,
#  'Деловая переписка': 523,
#  'Клиентоориентированность': 515,
#  'Обучение и развитие': 494,
#  'Поиск и привлечение клиентов': 479,
#  'Грамотность': 462,
#  'Работа с большим объемом информации': 420,
#  'Прямые продажи': 402,
#  'Заключение договоров': 357,
#  'Холодные продажи': 352,
#  'Ориентация на результат': 349,
#  'AutoCAD': 344,
#  'Управление персоналом': 342,
#  'Консультирование': 340,
#  '1С: Предприятие 8': 323,
#  'Обучение персонала': 322,
#  'Работа с людьми': 304,
#  'Водительское удостоверение категории B': 289,
#  'Навыки межличностного общения': 283,
#  'Деловая коммуникация': 282,
#  'Работа с кассой': 278,
#  'Знание устройства автомобиля': 275,
#  'Медицинская документация': 265,
#  'Умение работать в коллективе': 264,
#  'Английский язык': 262,
#  'Развитие продаж': 253,
#  'Документальное сопровождение': 246,
#  'B2B Продажи': 245,
#  'Контроль качества': 240,
#  'CRM': 227,
#  'Точность и внимательность к деталям': 218,
#  'Поиск информации в интернет': 218,
#  'Подбор персонала': 217,
#  'Ответственность': 212,
#  'Строительство': 212,
#  'оформление документации': 210,
#  'Работа с оргтехникой': 195,
#  'Материальная ответственность': 193,
#  'Управление продажами': 188,
#  'Работа с возражениями': 186,
#  'Мобильность': 185,
#  'Adobe Photoshop': 183,
#  'Консультативные продажи': 181,
#  'Контроль сроков годности': 181,
#  'Креативность': 180,
#  'Документооборот': 179,
#  'Общественное питание': 178,
#  'Электронная почта': 175,
#  'Ведение документации': 175,
#  'MS Outlook': 174,
#  'Складской Учет': 173,
#  'Инвентаризация': 173,
#  '1С: Документооборот': 173,
#  'Консультирование клиентов': 172,
#  'Ведение отчетности': 172,
#  'Проведение презентаций': 170,
#  'Работа в условиях многозадачности': 168,
#  'Консультирование клиентов по телефону': 167,
#  'MS PowerPoint': 163,
#  'Первичная документация': 163,
#  'Техническое обслуживание': 161,
#  'Делопроизводство': 161,
#  'Медицинское оборудование': 159,
#  '1С: Торговля': 158,
#  'Обслуживание покупателей': 156,
#  'Проведение инвентаризаций': 155,
#  '1С: Склад': 154,
#  'Управление проектами': 152,
#  'Коммуникабельность': 151,
#  'Кассовые операции': 150,
#  'Розничная торговля': 147,
#  'Ремонтные работы': 145,
#  'Проектная документация': 142,
#  'Приемка груза': 141,
#  'Водительское удостоверение категории BC': 138,
#  'Многозадачность': 137,
#  'Мерчандайзинг': 135,
#  'Работа с базами данных': 131,
#  'входящие звонки': 131,
#  'Навыки переговоров': 127,
#  'Навыки составления отчетности': 127,
#  '1C: Бухгалтерия': 125,
#  'Работа с дебиторской задолженностью': 123,
#  'Первичная бухгалтерская документация': 122,
#  'Выкладка товаров': 121,
#  'Internet': 120,
#  'Руководство коллективом': 120,
#  'Прием и распределение телефонных звонков': 120,
#  'Холодные звонки': 118,
#  'работа с текущей базой клиентов': 116,
#  'Планирование продаж': 116,
#  'Навыки презентации': 116,
#  'Кассовые документы': 112,
#  'Первичные документы': 112,
#  'Управление производством': 110,
#  'оформление заказов': 109,
#  'Стрессоустойчивость': 106,
#  'Работа с документами': 106,
#  'Бухгалтерская отчетность': 104,
#  'Управление производственным персоналом': 104,
#  'Управление отношениями с клиентами': 102,
#  'Закупка товаров и услуг': 100,
#  '1С: Бухгалтерия': 98,
#  'Чтение чертежей': 97,
#  'Организация мероприятий': 96,
#  'Работа с клиентами': 95,
#  'Сварочные работы': 95,
#  '1С: Торговля и склад': 93,
#  'Творческое мышление': 92,
#  'Обеспечение жизнедеятельности офиса': 90,
#  'Работа с поставщиками': 90,
#  'Ориентация на клиента': 89,
#  'Работа с ТМЦ': 88,
#  'Закупки': 88,
#  'MS Excel': 88,
#  'Ведение клиентской базы': 88,
#  'Учет товаров': 87,
#  'Монтаж оборудования': 86,
#  'Мотивация персонала': 85,
#  'исходящие звонки': 84,
#  'Ответственное хранение': 84,
#  'Складской документооборот': 82,
#  'Составление договоров': 82,
#  'Охрана труда и техника безопасности': 81,
#  'Сопровождение клиентов': 81,
#  'Планирование карьеры': 80,
#  'Способность обучать других': 80,
#  'Складская логистика': 78,
#  'Пополнение товарных запасов': 77,
#  'Кадровое делопроизводство': 76,
#  'Разработка проектной документации': 75,
#  'Аналитическое мышление': 75,
#  'MS Internet Explorer': 74,
#  'Деловая этика': 74,
#  'Прием посетителей': 74,
#  'Аналитика продаж': 74,
#  'Электронный документооборот': 74,
#  'Управление командой': 73,
#  'Расчет заработной платы': 73,
#  'Управленческая отчетность': 73,
#  'JavaScript': 72,
#  'Оценка потребностей клиентов': 72,
#  'Производство строительно-монтажных работ': 72,
#  'Git': 71,
#  'Умение планировать': 68,
#  'MS Office': 68,
#  'Turbo Pascal': 67,
#  'Транспортная логистика': 67,
#  'Навыки работы с первичной документацией': 67,
#  'Налоговая отчетность': 67,
#  'CorelDRAW': 67,
#  'Торговля': 66,
#  'B2C продажи': 66,
#  'Работа с жалобами клиентов': 66,
#  'HTML': 66,
#  'Умение принимать решения': 65,
#  'Инженерные системы': 64,
#  '1С: Зарплата и управление персоналом': 64,
#  'SQL': 63,
#  'Слесарные работы': 62,
#  'Офисная техника': 62,
#  '1С: Производство': 61,
#  'Интернет-реклама': 61,
#  'Вождение автомобилей представительского класса': 61,
#  'Исполнительность': 59,
#  'Управленческие навыки': 59,
#  'Настройка ПК': 59,
#  'Консультант плюс': 59,
#  'Подготовка коммерческих предложений': 58,
#  'Проведение промо акций': 56,
#  'Подготовка презентаций': 56,
#  'Договорная работа': 56,
#  'Ведение переписки': 56,
#  'PHP': 56,
#  '1С: Розница': 55,
#  'Управление временем': 55,
#  'Организация встреч': 55,
#  'Google Chrome': 54,
#  'Мерчендайзинг': 53,
#  'Linux': 53,
#  'Бухгалтерский учет': 53,
#  'Компас-3D': 53,
#  'Работа с юридическими лицами': 53,
#  'MySQL': 52,
#  'Высокая скорость печати': 52,
#  'Продвижение бренда': 51,
#  'Современная розница': 51,
#  'Продажи': 51,
#  'Маркетинговый анализ': 51,
#  'Автомобильные грузоперевозки': 50,
#  'телефонные продажи': 50,
#  'исполнение поручений руководителя': 49,
#  '1С: Управление персоналом': 49,
#  'Ответственность и пунктуальность': 49,
#  'Блочная выкладка товара': 49,
#  'CSS': 49,
#  '1С-Битрикс': 49,
#  '1С: Управление Торговлей': 48,
#  'Adobe Illustrator': 48,
#  'Традиционная розница': 47,
#  'Обучение': 47,
#  'Контроль дебиторской задолженности': 47,
#  'Навыки работы с возражениями': 47,
#  'Массовый подбор персонала': 47,
#  'Монтаж металлоконструкций': 46,
#  'Адаптация персонала': 46,
#  'MS Dos': 46,
#  'SMM': 46,
#  'Техническая эксплуатация': 45,
#  'Банк-клиент': 45,
#  'Опыт продаж': 45,
#  'Расстановка приоритетов': 44,
#  'Автомобильные перевозки': 43,
#  'Производственный контроль': 43,
#  'Администрирование': 43,
#  'Работа с компьютером': 42,
#  'Логистика': 42,
#  'Гибкость': 42,
#  'Контроль исполнения решений': 42,
#  'Настройка сетевых подключений': 42,
#  'Оперативный поиск информации в сети Интернет': 42,
#  '3 группа по электробезопасности': 42,
#  'Финансовая отчетность': 41,
#  'MS Access': 41,
#  'Технический контроль производства': 41,
#  'Умение работать в условиях многозадачности': 41,
#  'Контроль отгрузок': 40,
#  'Высшее образование': 40,
#  'Учет остатков': 40,
#  'Преподаватель': 40,
#  'Административная поддержка руководителя': 40,
#  'Исполнение личных поручений руководителя': 40,
#  'Претензионная работа': 39,
#  'Проектирование': 39,
#  'Сметы': 39,
#  'Организационные навыки': 39,
#  'нормативно-техническая документация': 38,
#  'MS Paint': 38,
#  'Windows 7': 38,
#  'Гражданское право': 37,
#  'Разработка технических заданий': 37,
#  'Ремонт ПК': 37,
#  'Согласование договоров': 37,
#  'Внутренний контроль': 37,
#  'MS Word': 37,
#  'работа с физическими лицами': 37,
#  'Копирайтинг': 37,
#  'Работа с претензиями': 36,
#  'Монтаж инженерных систем': 36,
#  'Охрана объекта': 36,
#  'Жилая недвижимость': 36,
#  'ТМЦ': 36,
#  'Internet Marketing': 35,
#  'Прием и распределение звонков': 35,
#  'Сборка ПК': 35,
#  'R-Keeper': 35,
#  'Коммуникабельность, ответственность': 34,
#  'Учет ТМЦ': 34,
#  'Чтение электросхем': 33,
#  'Python': 33,
#  'Должностные инструкции': 33,
#  'Внимательность': 33,
#  'Настройка ПО': 33,
#  'Adobe Acrobat': 33,
#  'Урегулирование конфликтов': 33,
#  'Желание работать и зарабатывать': 33,
#  'Написание текстов': 33,
#  'Аналитические способности': 32,
#  'Планирование': 32,
#  'Проведение переговоров': 32,
#  'Наполнение контентом': 32,
#  'Дизайн': 32,
#  'Ведение групп в социальных сетях': 32,
#  'реализация товаров и услуг': 31,
#  'Информационные технологии': 31,
#  'Внутренняя документация': 31,
#  'ЕСКД': 30,
#  'Желание обучаться': 30,
#  'Бюджетирование': 30,
#  'Общая психология': 30,
#  'Сопровождение строительства': 30,
#  'Бумажный документооборот': 30,
#  'Основные средства': 30,
#  '1С программирование': 30,
#  'Опытный пользователь ПК': 30,
#  'Оценка персонала': 29,
#  'Составление отчетности': 29,
#  'Учет материалов': 29,
#  'Android': 29,
#  'Кредитные договоры': 29,
#  'Акты сверок': 29,
#  'Производственное планирование': 29,
#  'Google Analytics': 29,
#  'Строительный контроль': 28,
#  'Уверенный пользователь ПК': 28,
#  'PostgreSQL': 28,
#  'ArchiCAD': 28,
#  'Водительское удостоверение категории BCE': 28,
#  'Сварка': 28,
#  'MS Project': 28,
#  'Мотивация': 28,
#  'jQuery': 28,
#  'Статистический анализ': 28,
#  'Планирование маркетинговых кампаний': 28,
#  'Прямой поиск': 28,
#  '1С: Бухгалтерия и склад': 28,
#  'Внутренние коммуникации': 27,
#  'HTML5': 27,
#  'Разработка инструкций': 27,
#  'Авансовые отчеты': 27,
#  'Google Docs': 27,
#  'Расчет затрат': 27,
#  'Строительное делопроизводство': 27,
#  'Дружелюбность': 27,
#  'Участие в Тендерах': 26,
#  'Целеустремленность': 26,
#  'Системы видеонаблюдения': 26,
#  'MS Visio': 26,
#  'Поварское дело': 26,
#  'Пожарная безопасность': 26,
#  'Собеседование': 26,
#  'Планирование рабочего дня руководителя': 26,
#  'Визуальный мерчандайзинг': 26,
#  'Графический дизайн': 26,
#  'Знание 1С': 26,
#  'Продажа страховых продуктов': 26,
#  'Google AdWords': 26,
#  'ООП': 26,
#  'Социальные сети': 26,
#  'Маркетинговые исследования': 25,
#  'Анализ рынка': 25,
#  'Удаленная работа': 25,
#  'Проектно-конструкторская деятельность': 25,
#  'Арбитражные суды': 25,
#  'Тайм-менеджмент': 25,
#  'Работа в режиме многозадачности': 25,
#  'Логистика поставок': 25,
#  'Компас': 24,
#  'Java': 24,
#  'Выездное обслуживание': 24,
#  'Оценка кандидатов': 24,
#  'Товароведение': 24,
#  'Контекстная реклама': 24,
#  'ПК': 24,
#  'MS Publisher': 24,
#  'Корпоративные продажи': 24,
#  'Государственные закупки': 23,
#  'Финансовый анализ': 23,
#  'Корпоративная этика': 23,
#  'исходящая корреспонденция': 23,
#  'Поддержка работы офиса': 23,
#  'Организация деловых поездок': 23,
#  'MS SQL': 23,
#  '3D Моделирование': 23,
#  'Инкассация': 23,
#  'SolidWorks': 23,
#  'Опрятность': 23,
#  'Гранд-смета': 23,
#  'Детская психология': 23,
#  'Подбор производственного персонала': 23,
#  'Организация рабочих мест': 23,
#  'Маркетинговые коммуникации': 23,
#  'Яндекс.Метрика': 23,
#  'Гарантийное обслуживание': 23,
#  'Экономический анализ': 22,
#  'Autodesk Revit': 22,
#  'Ведение активных клиентов': 22,
#  '1C: Предприятие': 22,
#  'Внимательность, ответственность': 22,
#  'Корпоративная культура': 22,
#  'Дизайн интерьера': 22,
#  'Бизнес-анализ': 22,
#  'Работа с ПК': 22,
#  'Взаимодействие с контрольными органами': 21,
#  'Составление смет': 21,
#  'CSS3': 21,
#  'Организация учебного процесса': 21,
#  'Анализ данных': 21,
#  'Анализ продаж': 21,
#  'Входящая корреспонденция': 21,
#  'Яндекс.Директ': 21,
#  'Физическая выносливость': 21,
#  'Электротехнические работы': 20,
#  'Excel': 20,
#  'Тендеры': 20,
#  'Доброжелательность': 20,
#  'Юридическая поддержка': 20,
#  'Пунктуальность': 20,
#  'Техническая поддержка': 20,
#  'Базы данных': 20,
#  'Технология производства': 20,
#  'Техническая документация': 20,
#  'Atlassian Jira': 20,
#  'Рекрутмент': 20,
#  'Проведение опросов клиентов': 19,
#  'Суды общей юрисдикции': 19,
#  'Сбор и анализ информации': 19,
#  'HoReCa': 19,
#  'Кадровое планирование': 19,
#  'первичный документооборот': 19,
#  'Тренинги': 19,
#  'Терминалы Сбора Данных': 19,
#  'Финансовый контроль': 19,
#  'Работа на складе': 19,
#  'Локальные сети': 19,
#  'Диагностика': 19,
#  'Отчетность в ПФР': 19,
#  'Аккуратность': 19,
#  'Строительно-отделочные работы': 19,
#  'Фотография': 19,
#  'SEO': 19,
#  'Мониторинг рынка': 19,
#  'Экспедирование': 19,
#  'Коммуникативные навыки': 19,
#  'Social Media Marketing': 19,
#  'Организация движения и учета документов': 18,
#  'Стратегическое мышление': 18,
#  'Skype': 18,
#  'Сканер': 18,
#  'Работа с чертежами': 18,
#  'Комплектация': 18,
#  'Телефонное интервью': 18,
#  'Гражданское строительство': 18,
#  'Отчетность в ФСС': 18,
#  'Деловой этикет': 18,
#  'Чистоплотность': 18,
#  'Юридическое сопровождение': 18,
#  'Развитие ключевых клиентов': 18,
#  'TCP/IP': 18,
#  'Архивирование': 18,
#  'Грамотная устная и письменная речь': 18,
#  'Разработка маркетинговой стратегии': 18,
#  'Верстка': 18,
#  'Лечебная деятельность': 17,
#  'Продажи через дистрибьюторов': 17,
#  'Малярные работы': 17,
#  'Вежливость': 17,
#  'Знание компьютера': 17,
#  'Проектирование зданий и сооружений': 17,
#  'Технические системы и средства безопасности': 17,
#  'Деловая корреспонденция': 17,
#  'Системное мышление': 17,
#  'Mathcad': 17,
#  'Ведение архива': 17,
#  'Управление складскими запасами': 17,
#  'аккуратность': 17,
#  'Администрирование приема, перевода и увольнения сотрудников': 17,
#  'Проведение ревизий': 17,
#  'Спортивное питание': 16,
#  'Схемотехника электронного оборудования': 16,
#  'Ценообразование': 16,
#  'Solid Works': 16,
#  '3ds Max': 16,
#  'Пуско-наладочные работы': 16,
#  'Статистическая отчетность': 16,
#  'Расчет НДС': 16,
#  'Оптимизация бизнес-процессов': 16,
#  '1С: Управление Производственным Предприятием': 16,
#  'Станки ЧПУ': 16,
#  'Подготовка отчетов': 16,
#  'Составление исков': 16,
#  'Написание статей': 16,
#  '1С: Зарплата и кадры': 16,
#  'Управление качеством': 16,
#  'Работоспособность': 16,
#  'пунктуальность': 15,
#  'Гражданское процессуальное право': 15,
#  'Электрические системы и слаботочные системы': 15,
#  'Аналитические исследования': 15,
#  'SAP': 15,
#  'Малоэтажное строительство': 15,
#  'Active Directory': 15,
#  'Уборка': 15,
#  'Работа с ключевыми клиентами': 15,
#  'C#': 15,
#  'amoCRM': 15,
#  'регистрация документации': 15,
#  'Лидерство': 15,
#  'Управление интернет-проектами': 15,
#  'Adobe InDesign': 15,
#  'Умение расставлять приоритеты': 15,
#  'Электромонтажные работы': 14,
#  'Навыки телефонных продаж': 14,
#  'Node.js': 14,
#  'Администрирование сетевого оборудования': 14,
#  'B2B маркетинг': 14,
#  'Табель учета рабочего времени': 14,
#  '1C: Зарплата и кадры': 14,
#  'Бронирование гостиниц': 14,
#  'Протоколирование': 14,
#  'Ресторанный менеджмент': 14,
#  'Умение работать с людьми': 14,
#  'Таргетинг': 14,
#  'Агентские продажи': 14,
#  'Оптимизация логистических процессов': 14,
#  'Формирование бюджета': 14,
#  'Желание зарабатывать': 14,
#  'Взыскание задолженности': 14,
#  'ВЭД': 14,
#  'Недвижимость': 14,
#  'Индивидуальное обучение': 14,
#  'Docker': 14,
#  'Способность быстро обучаться': 14,
#  'Оформление больничных листов и отпусков': 14,
#  'Системы канализации и водоснабжения': 14,
#  'Гарант': 13,
#  'C++': 13,
#  'Умение общаться с людьми': 13,
#  'Приготовление продукции': 13,
#  'Выдача заказов': 13,
#  'Поддержание чистоты': 13,
#  'Карьерный рост': 13,
#  'Охрана труда': 13,
#  'Бронирование билетов': 13,
#  'разработка чертежей': 13,
#  'Российские стандарты бухгалтерского учета': 13,
#  'Реклама': 13,
#  'Знание города': 13,
#  'Расчеты с покупателями': 13,
#  'Контроль исправности оборудования': 13,
#  'Лабораторная работа': 13,
#  'Умение слушать': 13,
#  'Стабильность': 13,
#  'Графические редакторы': 13,
#  'Наружная реклама': 13,
#  'XML': 13,
#  'Кредиторская задолженность': 13,
#  'Ответственный подход к работе': 13,
#  '1С: Предприятие': 13,
#  'SEO оптимизация': 13,
#  'Привлечение клиентов': 13,
#  'Опрятный внешний вид': 13,
#  'первичная обработка документации': 13,
#  'Контроль оформления документов': 13,
#  'Планирование закупок': 13,
#  'внимательность': 13,
#  'Bootstrap': 13,
#  'Тестирование': 13,
#  'Списание ТМЦ': 13,
#  'Немецкий язык': 13,
#  'Составление предложений о работе': 13,
#  'Трудоспособность': 13,
#  '1С: Предприятие: Розница': 13,
#  'Обучаемость': 13,
#  'Банкротство': 12,
#  'Материальная отвественность': 12,
#  'Информационная безопасность': 12,
#  'Сосредоточенность': 12,
#  'Анализ конкурентной среды': 12,
#  'Работа на выставках': 12,
#  'Инициативность': 12,
#  'Деревообработка': 12,
#  'Эксплуатация': 12,
#  'Автоматизированное рабочее место (АРМ)': 12,
#  'Водительское удостоверение категории BCD': 12,
#  'Грузовой транспорт': 12,
#  'Финансовое планирование': 12,
#  'Управление затратами': 12,
#  'Cистемы управления базами данных': 12,
#  'Сельское хозяйство': 12,
#  'Способность к обучению и восприятию информации': 12,
#  'Закупка оргтехники и оборудования': 12,
#  'Административное управление': 12,
#  'Разработка концепции': 12,
#  'Ведение кассовой книги': 12,
#  'Видеомонтаж': 12,
#  'Штатное расписание': 12,
#  'Взаимодействие с государственными контролирующими органами': 12,
#  'Трудовой кодекс РФ': 12,
#  'Обработка изображений': 12,
#  'Аналитический склад ума': 12,
#  'Материально-техническое обеспечение': 12,
#  '1С: Комплексная автоматизация': 12,
#  'Умение работать в режиме многозадачности': 12,
#  'Оприходование товара': 12,
#  'Знание иностранных языков': 12,
#  'Веб-аналитика': 12,
#  'входящая документация': 12,
#  'Физическая подготовка': 11,
#  'Проведение тендеров': 11,
#  'Знание MS Office': 11,
#  'Расчет себестоимости': 11,
#  'Кадровая политика': 11,
#  'Дорожное строительство': 11,
#  'Redis': 11,
#  'Психология': 11,
#  'Сборочное производство': 11,
#  'прохождение налоговых проверок': 11,
#  'Кладовщик': 11,
#  'Выносливость': 11,
#  'MS Movie Maker': 11,
#  'Движение денежных средств': 11,
#  'Вторичная недвижимость': 11,
#  'Первичная недвижимость': 11,
#  'Телемаркетинг': 11,
#  'Дистанционное обучение': 11,
#  'Умение работать с клиентами': 11,
#  'Гражданский кодекс РФ': 11,
#  'Организация хранения документации': 11,
#  'Администрирование серверов Windows': 11,
#  'Публичные выступления': 11,
#  'Дисциплинированность': 11,
#  'Социальная психология': 11,
#  'Анализ бизнес показателей': 11,
#  'Расчет зарплаты': 11,
#  'Контроль поставок': 11,
#  'Ajax': 11,
#  'Бизнес-планирование': 11,
#  'Групповое обучение': 11,
#  'Расчет налогов': 11,
#  'Коммуникабельность, стрессоустойчивость': 11,
#  'Консультирование сотрудников по вопросам трудового законодательства': 11,
#  'Формирование планов по подбору персонала': 10,
#  'React': 10,
#  'Взаимодействие с органами государственного контроля': 10,
#  'Системы охранно-тревожной сигнализации': 10,
#  'Windows Xp': 10,
#  'Оперативное планирование': 10,
#  'обучение сотрудников': 10,
#  'Проектный менеджмент': 10,
#  'Продвинутый пользователь ПК': 10,
#  'Управленческий учет': 10,
#  'Интернет маркетинг': 10,
#  'Фотомонтаж': 10,
#  'Symfony': 10,
#  'B2C маркетинг': 10,
#  'Навыки разрешения спорных ситуаций': 10,
#  'Автоматизация технологических процессов': 10,
#  'Autodesk 3ds Max': 10,
#  'Опыт судебных разбирательств': 10,
#  'Сопровождение сделок': 10,
#  'Медиапланирование': 10,
#  'Вождение трактора': 10,
#  'Продажи физическим лицам': 10,
#  'Стремление к профессиональному росту': 10,
#  'Организация презентаций': 10,
#  'Обновление конфигурации 1С': 10,
#  'Водительское удостоверение категории A': 10,
#  'Дебиторская задолженность': 10,
#  'Сборка мебели': 10,
#  'Передача документации на исполнение': 10,
#  'Проведение внутренних расследований': 10,
#  'Проведение опросов': 10,
#  'Проведение телефонных интервью': 10,
#  'Организация и планирование рабочего времени': 10,
#  'продажа недвижимости': 10,
#  'Развитие бренда': 10,
#  'Организация стажировок': 10,
#  'Аутсорсинг': 10,
#  'Nginx': 10,
#  'Навыки коммуникации': 10,
#  'Спортивные мероприятия': 10,
#  'Массовое производство': 10,
#  'Линейная выкладка товара': 10,
#  '1C: Финансы': 9,
#  'Желание учиться и развиваться': 9,
#  'технологические карты': 9,
#  'Spring Framework': 9,
#  'Ответственность и исполнительность': 9,
#  'Фитнес': 9,
#  'Yii': 9,
#  'Microsoft Access': 9,
#  'Навыки делового общения': 9,
#  'Системы безопасности': 9,
#  'Водоснабжение и канализация': 9,
#  'Управление лояльностью потребителей': 9,
#  'обработка входящей корреспонденции': 9,
#  'Административно-хозяйственная деятельность': 9,
#  'Позитивный настрой': 9,
#  'Добросовестность': 9,
#  'Самостоятельное ведение кадрового документооборота': 9,
#  'Продажи запчастей для иностранных автомобилей': 9,
#  'Платежные поручения': 9,
#  'Продажи через интернет': 9,
#  'Автоматизация документооборота': 9,
#  'Общение с клиентами': 9,
#  'Управление бюджетом': 9,
#  'CMS Wordpress': 9,
#  'Взаимодействие с надзорными организациями': 9,
#  'Стропальщик': 9,
#  'Психология Личности': 9,
#  'SCAD': 9,
#  'Продвижение в социальных группах': 9,
#  'Трудовое законодательство РФ': 9,
#  'Умение вести переговоры': 9,
#  'вахта': 9,
#  'MongoDB': 9,
#  'Подбор сотрудников': 9,
#  'Бережливое производство': 9,
#  'Письменный перевод': 9,
#  'Вводный инструктаж по охране труда и технике безопасности': 9,
#  'Маркетинговое планирование': 9,
#  'Воинский учет': 9,
#  'Анализ себестоимости': 9,
#  'Анализ затрат': 9,
#  'Мониторинг цен': 9,
#  'Маникюр': 9,
#  'Гостиницы': 9,
#  'Знание техники продаж': 9,
#  'Химические методы анализа': 9,
#  'Штукатурные работы': 9,
#  'Управление секретариатом': 9,
#  'обучаемость': 9,
#  'Хорошая обучаемость': 9,
#  'ANSYS': 9,
#  'Технический надзор': 9,
#  'Ведение деловой переписки': 8,
#  'принимать решения и за их результаты отвечать самостоятельно': 8,
#  'Управление офисами компании': 8,
#  'Анализ текущих финансовых показателей': 8,
#  'PHP5': 8,
#  'Математический анализ': 8,
#  'Предпечатная подготовка': 8,
#  'Выбор подрядных организаций': 8,
#  'Pascal': 8,
#  'Организация работы приемной': 8,
#  'Техническая грамотность': 8,
#  '1С: Предприятие: Бухгалтерский Учет': 8,
#  'Opera': 8,
#  'Управление рисками': 8,
#  'Битрикс24': 8,
#  'Web-дизайн': 8,
#  'Продажи юридическим лицам': 8,
#  'Электрика': 8,
#  'Поисковые системы': 8,
#  'UI': 8,
#  'Контроль отгрузки и доставки товара': 8,
#  'Предметная фотосъемка': 8,
#  'Microsoft Office': 8,
#  'Технологии производства блюд': 8,
#  'Участок "Касса"': 8,
#  'iOS': 8,
#  'Продажи корпоративным клиентам': 8,
#  'Юридический консалтинг': 8,
#  'Сверка взаиморасчетов с поставщиками товаров и услуг': 8,
#  'Helpdesk': 8,
#  'дисциплинированность': 8,
#  'Договоры поставки': 8,
#  'Взаимодействие с правоохранительными органами': 8,
#  'WEB аналитика': 8,
#  'Функциональное тестирование': 8,
#  'Трудовое право': 8,
#  'Подбор недвижимости по запросу клиента': 8,
#  'Бетонные работы': 8,
#  'Веб-программирование': 8,
#  'Разработка нового продукта': 8,
#  'Исходящая документация': 8,
#  'Налоговое законодательство': 8,
#  'Точность и внимательность': 8,
#  'Умение читать чертежи': 8,
#  'КИПиА': 8,
#  'Статистика': 8,
#  'Грузоперевозки': 8,
#  'Составление бизнес-плана': 8,
#  'грамотная русская речь (устная и письменная)': 8,
#  'Педикюр': 8,
#  'Общестроительные работы': 8,
#  'Региональные сети': 8,
#  'Административное право': 8,
#  'Adobe After Effect': 8,
#  'Работа в коллективе': 8,
#  'Портретная фотосъемка': 8,
#  'работа с VIP клиентами': 8,
#  'Мобильный мерчандайзинг': 8,
#  'Отчетность в государственные фонды': 8,
#  'Испанский язык': 8,
#  'Cоциальный маркетинг': 8,
#  'Тактичность': 8,
#  'Вахта': 8,
#  'Начисление ежегодных отпусков': 8,
#  'Внутренняя логистика': 8,
#  'Взаимодействие с разрешительными органами': 8,
#  'Знание законодательства': 8,
#  'Водительские права категории В': 7,
#  'Высокая энергичность': 7,
#  'REST': 7,
#  'Металлообработка': 7,
#  'Маркетинг услуг': 7,
#  'Выявление потребностей в обучении': 7,
#  'Капитальный ремонт': 7,
#  'менеджер': 7,
#  'Autodesk Inventor': 7,
#  '3D Max': 7,
#  'Терпеливость': 7,
#  'База данных: Outlook': 7,
#  'Продажа дополнительных услуг и оборудования': 7,
#  'OpenOffice': 7,
#  'Налоговый учет': 7,
#  'FMCG Продажи': 7,
#  'Непрерывное производство': 7,
#  'Маркетинг': 7,
#  'Планирование рекламных кампаний': 7,
#  'Приходные и расходные кассовые ордера': 7,
#  'Работа с первичной документацией': 7,
#  'кадровый учет': 7,
#  'Техники продаж': 7,
#  'умение работать в команде': 7,
#  'Европейская кухня': 7,
#  'Стандарты гостеприимства': 7,
#  '1С: Управление предприятием': 7,
#  'UX': 7,
#  'BPMN': 7,
#  'Восстановление кадрового документооборота': 7,
#  'Производство пусконаладочных работ': 7,
#  'Промышленная безопасность': 7,
#  'Обработка видео': 7,
#  'Женские стрижки': 7,
#  'Мужские стрижки': 7,
#  'Умение легко находить контакт с людьми': 7,
#  'Личный автомобиль': 7,
#  'планировать и оптимально организовать рабочий процесс': 7,
#  'Стоматология': 7,
#  'без опыта': 7,
#  'подработка': 7,
#  'Работа с существующей базой клиентов': 7,
#  'Работа с электроинструментом': 7,
#  'Исследования рынка труда': 7,
#  'Продвижение сайтов': 7,
#  'Высокая энергичность и инициативность': 7,
#  'Таможенное оформление': 7,
#  'Управление HR брендом': 7,
#  'Управление строительством': 7,
#  'Аттестация персонала': 7,
#  'Стратегический маркетинг': 7,
#  'Создание, развитие и ведение клиентской базы': 7,
#  'Написание рекламных статей': 7,
#  'Логистический менеджмент': 7,
#  'Продвижение объекта': 7,
#  'Геодезия': 7,
#  'Работа с локальными сетями': 7,
#  'Figma': 7,
#  'Kotlin': 7,
#  'Windows Os': 7,
#  'Администрирование сайтов': 7,
#  'Конкурентная аналитика': 7,
#  'Курьер': 7,
#  'Каменные работы': 7,
#  'API': 7,
#  'Готовность обучаться': 7,
#  'Опытный пользовать ПК, знание MS Office': 7,
#  'Разработка электросхем': 7,
#  'Заказ такси': 7,
#  'Kubernetes': 7,
#  'Спокойствие': 7,
#  'строительно-монтажные работы': 7,
#  'Работа с детьми': 7,
#  'Постановка задач разработчикам': 7,
#  'Поиск персонала в открытых источниках': 7,
#  'Оформление возврата продукции': 7,
#  'Педиатрия': 6,
#  'Поиск и подбор помещения': 6,
#  'Офисные программы': 6,
#  'Управление талантами': 6,
#  'Laravel': 6,
#  'Организация безопасной эксплуатации оборудования': 6,
#  'Внимательность к мелочам': 6,
#  'Прокладка кабелей': 6,
#  'Отчет о прибылях и убытках': 6,
#  'Контроль состояния оборудования': 6,
#  'Экономическая безопасность': 6,
#  'Страхование': 6,
#  'Управление складом': 6,
#  'Повременно-премиальная оплата труда': 6,
#  'MS SQL Server': 6,
#  'JSON API': 6,
#  'Грамотная письменная речь': 6,
#  'Продажа кредитных продуктов': 6,
#  '1С: CRM ПРОФ': 6,
#  'MS CRM': 6,
#  'Дизайн интерфейсов': 6,
#  'Оценка недвижимости': 6,
#  'Элитная недвижимость': 6,
#  'Django Framework': 6,
#  'Составление семантического ядра': 6,
#  'UML': 6,
#  'Системный анализ': 6,
#  'Высокие коммуникативные навыки': 6,
#  'Автоматизация склада': 6,
#  'Государственные структуры': 6,
#  'Вентиляция и кондиционирование': 6,
#  'проведение интервью': 6,
#  'Выездные мероприятия': 6,
#  'Управление документооборотом': 6,
#  'Водитель': 6,
#  'Знания и умения по специальности': 6,
#  'Умение организовывать работу': 6,
#  'Регрессионное тестирование': 6,
#  'PR': 6,
#  'Отчетность': 6,
#  'Анализ финансовых показателей': 6,
#  'Корпоративное право': 6,
#  'Адаптация': 6,
#  'Барное ремесло': 6,
#  'Работа с документами временного хранения': 6,
#  'комплектовщик': 6,
#  'начинающий специалист': 6,
#  'Составление планов по подбору': 6,
#  'Ипотечное кредитование': 6,
#  'АСУ ТП': 6,
#  'Аутстаффинг': 6,
#  'Федеральные сети': 6,
#  'Проведение собеседований': 6,
#  'Выполнение технического надзора': 6,
#  'Tilda': 6,
#  'Производство рекламных материалов': 6,
#  'iiko': 6,
#  'Compass 3D': 6,
#  'разработка инструкций по охране труда': 6,
#  'Гостиничный менеджмент': 6,
#  'Договоры подряда': 6,
#  'Не конфликтность': 6,
#  'проведение переговоров с первыми лицами компании': 6,
#  'Управление сотрудниками в регионах': 6,
#  'Стационарный мерчандайзинг': 6,
#  'Энтузиазм': 6,
#  'Компьютер': 6,
#  'Управление цепочкой поставок': 6,
#  'Лидогенерация': 6,
#  'B2B Marketing': 6,
#  'СУБД': 6,
#  'Готовность к командировкам': 6,
#  'Косметология': 6,
#  'Оптимизация затрат': 6,
#  'DHCP': 6,
#  'Участие в профессиональных выставках': 6,
#  'Экологическая безопасность': 6,
#  'Энергетика': 6,
#  'Официальное трудоустройство': 6,
#  'Оформление трудовых книжек': 6,
#  'администратор': 6,
#  'кассир': 6,
#  'Business English': 6,
#  'План продвижения': 6,
#  'Scrum': 6,
#  'Графика': 6,
#  'Проведение праздников': 6,
#  'MVC': 6,
#  'СБиС': 6,
#  'системы вентиляции и кондиционирования': 6,
#  'Вождение дизельного погрузчика': 6,
#  'CorelDRAW Photo Draw': 6,
#  'Студийная фотосъемка': 6,
#  'Adobe Premier Pro': 6,
#  'Управление товарными запасами': 6,
#  'Less': 5,
#  'Технические средства информационной защиты': 5,
#  'подготовка документов для участия в тендерах': 5,
#  'Ruby': 5,
#  'SOAP': 5,
#  'Hibernate ORM': 5,
#  'Agile Project Management': 5,
#  'Angular': 5,
#  'Администрирование процесса обучения': 5,
#  'Ввод в эксплуатацию': 5,
#  'Mac Os': 5,
#  'Способность работать в режиме многозадачности': 5,
#  'Бизнес-консультирование': 5,
#  'Управление финансами': 5,
#  'Правовые системы': 5,
#  'Планирование и организация': 5,
#  'ERP-системы на базе 1С': 5,
#  'Обеспечение техники безопасности': 5,
#  'Лицензия охранника': 5,
#  'Слепая печать': 5,
#  'Рисунок': 5,
#  'Массаж': 5,
#  'Классический массаж': 5,
#  'Загородная недвижимость': 5,
#  'Участок "Банк-Клиент"': 5,
#  'Желание работать и развиваться': 5,
#  'Безопасность': 5,
#  'Android SDK': 5,
#  'Управление офисными водителями': 5,
#  'Расчеты с поставщиками': 5,
#  'Видеосъемка': 5,
#  'Sony Vegas': 5,
#  'Опыт работы с людьми': 5,
#  'водитель': 5,
#  'опыт работы': 5,
#  'Умение находить общий язык': 5,
#  'Проверка контрагентов': 5,
#  'Кадровая безопасность': 5,
#  'Окрашивание волос': 5,
#  'Маркетплейсы': 5,
#  'производство': 5,
#  'Диспетчер': 5,
#  'Zabbix': 5,
#  'Администрирование серверов Linux': 5,
#  'Оптимизация закупок': 5,
#  'чтение чертежей': 5,
#  'Командообразование': 5,
#  ...}

# %%
# your code here
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 3
#       1 # your code here
#       2 # Очистим записи с пустым списком ключевых навыков
# ----> 3 temp_df = df_train.loc[df_train['key_skills'].count == 0]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1430, in _LocIndexer._getitem_axis(self, key, axis)
#    1427         return self.obj.iloc[tuple(indexer)]
#    1429 # fall thru to straight lookup
# -> 1430 self._validate_key(key, axis)
#    1431 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1239, in _LocIndexer._validate_key(self, key, axis)
#    1232 ax = self.obj._get_axis(axis)
#    1233 if isinstance(key, bool) and not (
#    1234     is_bool_dtype(ax.dtype)
#    1235     or ax.dtype.name == "boolean"
#    1236     or isinstance(ax, MultiIndex)
#    1237     and is_bool_dtype(ax.get_level_values(0).dtype)
#    1238 ):
# -> 1239     raise KeyError(
#    1240         f"{key}: boolean label can not be used without a boolean index"
#    1241     )
#    1243 if isinstance(key, slice) and (
#    1244     isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1245 ):
#    1246     raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %% [markdown]
# **Визуализацию данных из тестового датасета мы предлагаем вам сделать самостоятельно**. Вполне может оказаться так, что они сильно отличаются от трейна.

# %%
# your code here

# %% [markdown]
# Постройте облако слов в описаниях вакансий

# %% [markdown]
# # Preprocessing

# %% [markdown]
# В бейзлайне используем только описание и название вакансии. **Попробуйте в своих моделях учесть и другие признаки**.

# %%
df_train_new = pd.DataFrame()
df_train_new['text'] = df_train.name + ' ' + df_train.description
df_train_new
# Out:
#                                                     text
# 0      Водитель-экспедитор Водитель-экспедитор катего...
# 1      Кладовщик-комплектовщик/оператор 1С Обязанност...
# 2      Продавец магазина "Магнит" (Кировский р-он, В....
# 3      Администратор магазина (ТЦ Spar) Крупная федер...
# 4      Мойщик посуды (кулинария) Обязанности:  Уборка...
# ...                                                  ...
# 16624  Полицейский специального полка полиции Обязанн...
# 16625  Врач стоматолог-ортопед (г. Новосибирск) Обяза...
# 16626  Фармацевт Условия:  официальное оформление по ...
# 16627  Геодезист (автодороги) Обязанности:  своевреме...
# 16628  Специалист-эксперт отдела правового обеспечени...
#
# [16629 rows x 1 columns]

# %%
stop_words = set(stopwords.words('russian'))
morph = MorphAnalyzer()

# функция для очистки описаний
def clean_text(text):
    text = re.sub(r'http\S+', '', text) # избавляемся от ссылок
    text = re.sub('[^а-яёА-ЯЁ]', ' ', text) # оставляем только кириллицу
    text = word_tokenize(text.lower()) # приводим к нижнему регистру и токенизируем по словам
    # приводим токены к нормальной форме, удаляем стоп-слова и короткие токены
    text = [morph.normal_forms(token)[0] for token in text
            if token not in stop_words and len(token) > 2]
    text = " ".join(text) # возвращаем строку
    return text

# %%
# %time df_train_new['cleaned'] = df_train_new.text.apply(clean_text)
df_train_new
# Out:
# CPU times: user 4min 39s, sys: 715 ms, total: 4min 40s
# Wall time: 4min 43s
#                                                     text  \
# 0      Водитель-экспедитор Водитель-экспедитор катего...
# 1      Кладовщик-комплектовщик/оператор 1С Обязанност...
# 2      Продавец магазина "Магнит" (Кировский р-он, В....
# 3      Администратор магазина (ТЦ Spar) Крупная федер...
# 4      Мойщик посуды (кулинария) Обязанности:  Уборка...
# ...                                                  ...
# 16624  Полицейский специального полка полиции Обязанн...
# 16625  Врач стоматолог-ортопед (г. Новосибирск) Обяза...
# 16626  Фармацевт Условия:  официальное оформление по ...
# 16627  Геодезист (автодороги) Обязанности:  своевреме...
# 16628  Специалист-эксперт отдела правового обеспечени...
#
#                                                  cleaned
# 0      водитель экспедитор водитель экспедитор катего...
# 1      кладовщик комплектовщик оператор обязанность с...
# 2      продавец магазин магнит кировский уса крупный ...
# 3      администратор магазин крупный федеральный сеть...
# 4      мойщик посуда кулинария обязанность уборка про...
# ...                                                  ...
# 16624  полицейский специальный полка полиция обязанно...
# 16625  врач стоматолог ортопед новосибирск обязанност...
# 16626  фармацевт условие официальный оформление графи...
# 16627  геодезист автодорога обязанность своевременный...
# 16628  специалист эксперт отдел правовой обеспечение ...
#
# [16629 rows x 2 columns]

# %%
df_test_new = pd.DataFrame()
df_test_new['text'] = df_test.name + ' ' + df_test.description
# %time df_test_new['cleaned'] = df_test_new['text'].apply(clean_text)
# Out:
# CPU times: user 1min 35s, sys: 294 ms, total: 1min 36s
# Wall time: 1min 37s

# %%
df_test_new
# Out:
#                                                    text  \
# 0     Главный бухгалтер Обязанности:Осуществление ор...
# 1     Ассистент врача-стоматолога Обязанности:  Асси...
# 2     Менеджер по продажам Если ты:    хочешь постро...
# 3     Менеджер   Динамично развивающаяся на протяжен...
# 4     Администратор хостела ВОЗМОЖНА РАБОТА С ПРОЖИВ...
# ...                                                 ...
# 5538  Специалист по дистанционному контролю качества...
# 5539  Продавец-консультант Компания ONE SMOKE пригла...
# 5540  Фельдшер скорой медицинской помощи Обязанности...
# 5541  Продавец-консультант Мечтаешь быть уникальной?...
# 5542  Торговый представитель (Колпино, Тосно, Кировс...
#
#                                                 cleaned
# 0     главный бухгалтер обязанность осуществление ор...
# 1     ассистент врач стоматолог обязанность ассистир...
# 2     менеджер продажа хотеть построить карьера банк...
# 3     менеджер динамично развивающийся протяжение го...
# 4     администратор хостел возможный работа проживан...
# ...                                                 ...
# 5538  специалист дистанционный контроль качество янд...
# 5539  продавец консультант компания приглашать сотру...
# 5540  фельдшер скорый медицинский помощь обязанность...
# 5541  продавец консультант мечтать уникальный хотеть...
# 5542  торговый представитель колпино тосно кировск к...
#
# [5543 rows x 2 columns]

# %% [markdown]
# Рекомендуем **попробовать разные сочетания предобработки текста, векторизаторов и моделей в дальнейшем**

# %%
# your code here

# %% [markdown]
# # Tf-Idf

# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Lasso

# %%
tfidf = TfidfVectorizer()
X_train = tfidf.fit_transform(df_train_new.cleaned)
X_train
# Out:
# <16629x76873 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1746933 stored elements in Compressed Sparse Row format>

# %%
X_test = tfidf.transform(df_test_new.text)
X_test
# Out:
# <5543x76873 sparse matrix of type '<class 'numpy.float64'>'
# 	with 569038 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Попробуйте OHE, bag-of-words. Используйте разные n-граммы**

# %%
# your code here

# %% [markdown]
# # Fit & Predict

# %% [markdown]
# Применяем Lasso-регрессию. **Наверняка стоит попробовать более сложные модели и потюнить гиперпараметры** ([хендбук](https://education.yandex.ru/handbook/ml/article/podbor-giperparametrov), [Хабр](https://habr.com/ru/companies/otus/articles/754402/))

# %%
lasso = Lasso()
lasso.fit(X_train, df_train.salary)
y_pred = lasso.predict(X_test)

# %%
# your code here

# %% [markdown]
# # Catboost
# В этом блоке советуем **попытаться запустить catboost**. Для этого в конструкторе класса `CatBoostRegressor` ([документация](https://catboost.ai/en/docs/concepts/python-reference_catboostregressor)) нужно в параметре `text_features` перечислить текстовые фичи. И ждать магии

# %%
# your code here

# %% [markdown]
# ## Прочие рекомендации
#
# * **не игонрируйте этап разведочного анализа данных: чем подробнее и глубже вы его сделаете, тем более последовательно вы будете двигаться к лучшему вашему решению**
# * **вы можете попробовать какую-то другую токенизацию; возможно в бейзлайне мы не учли что-то важное**
# * **разумно попробовать учесть те признаки, что мы проигнорировали в базовом решении (хотя бы банальный OHE-encoding)**
#
#
# ### Дальше в ходе студкемпа мы научимся:
# * **пользоваться Word2Vec (обучать с нуля, что не очень используется; или же использовать предобученную и дообучать на текстах задачи)**
# * **для перехода к числовым представлениям слов можно попробовать и другие модели: GloVe, fastText, Doc2Vec**
# * **или даже расчехлить не слишком тяжеловесные трансформерные**
#
# Улучшите качество модели на вашей валидационной выборке настолько, насколько выйдет

# %%
# your code here

# %% [markdown]
# # Анализ результатов
#
# Проведите аналитику результатов. Сравните модели и способы предобработки. Укажите, каким образом удалось добиться наилучшего качества. Перечислите достоинства и недостатки для прода простых (a la OHE) и сложных (catboost с подобранными гиперпараметрами) моделей. Если время на эксперименты всё, то напишите свои мысли, как можно было бы улучшить прогноз
